# %% [markdown]
# Notebook for working on custom tools for agents

# %%
import requests
from bs4 import BeautifulSoup

# %%
resp = requests.get("https://www.bbc.com/")

# %%
soup = BeautifulSoup(resp.text, "html.parser")

# %%
headings = ["h1", "h2", "h3", "h4", "h5", "h6"]
anchors = soup.find_all("a")

pairs = []

for a in anchors:
    if any(a.find(heading) for heading in headings):
        pairs.append((a.text.strip(), a.get("href")))

# %%
for pair in pairs:
    print(f"{pair[0][:100]} - {pair[1]}")
# Out:
# LIVEIsrael attacks Fordo nuclear site, as Trump floats 'regime change' after US strikes - https://www.bbc.com/news/live/cn7ze4vmk2pt
# Strait of Hormuz: What happens if Iran shuts global oil corridor? - /news/articles/c78n6p09pzno
# An unprecedented moment - but what the US and Iran do next could be even more momentous - /news/articles/cy0w94yj68xo
# Decoy flights and seven B-2 stealth bombers - how US says it hit Iran's nuclear sites - /news/articles/cew0x7159edo
# US strikes on Iran trigger protests internationally - /news/videos/c4g2wxwel5qo
# Bride shot dead in attack on French wedding partyA suspected attacker is also killed in an apparent  - /news/articles/cn0q8pypxwxo
# First celestial image unveiled from revolutionary telescopeThe telescope should detect killer astero - /news/articles/cj3rmjjgx6xo
# Bride shot dead in attack on French wedding partyA suspected attacker is also killed in an apparent  - /news/articles/cn0q8pypxwxo
# First celestial image unveiled from revolutionary telescopeThe telescope should detect killer astero - /news/articles/cj3rmjjgx6xo
# Seven killed in Kyiv in new Russian aerial attack - /news/articles/c0k7vll16l3o
# Russia's economy is down but not outThe country's economy has been surprisingly resilient but there  - /news/articles/cpqnj17vryjo
# Gilgeous-Alexander guides Thunder to NBA gloryShai Gilgeous-Alexander caps a dominant season as the  - /sport/basketball/articles/c4gdp135vvgo
# 'Our sister died of cancer because of our mum's conspiracy theories'Paloma Shemirani’s brothers say  - /news/articles/crenzwyvpn1o
# Tesla robotaxi 'low-key' launch in Texas27 mins agoTechnology - /news/articles/cjwnlje3yp1o
# The story of the first ever Glastonbury FestivalAlmost 55 years ago, Michael Eavis hosted the first  - /culture/article/20250620-the-story-of-the-first-ever-glastonbury-festival-in-1970
# Why an apple a day is really good for youWe're told an apple a day keeps the doctor away, but does t - /future/article/20250620-is-an-apple-a-day-really-good-for-your-health
# US strikes Iran: UN chief warns against cycle of retaliation - /audio/play/p0lkv3m9
# Also in news - https://www.bbc.com/news/world
# Indian investigators now claim all Pahalgam attackers were Pakistan nationalsIndian investigators ha - /news/articles/c36xe95g06zo
# Caught in the crossfire - the victims of Cape Town's gang warfareChildren are the unwitting casualti - /news/articles/c1mg2xg339jo
# Giant Michael Jackson statues popped up 30 years ago. Where have they gone?The King of Pop had 10 st - /news/articles/cn0q2krypkro
# When Dubai almost became a part of India It's now largely forgotten that in the early 1900s, nearly  - /news/articles/cgq3wlp22j9o
# Cars, cash and a tycoon stirring debate in ZimbabweSome are beguiled by the Zimbabwean tycoon's gene - /news/articles/cn81ynyjy8no
# Caught in the crossfire - the victims of Cape Town's gang warfareChildren are the unwitting casualti - /news/articles/c1mg2xg339jo
# 'Tourists are our lifeline': Picking up the pieces in Kashmir after April killingsTwenty-six people  - /news/articles/cly8lx75d6ro
&at_bbc_team=studios&at_medium=display&at_objective=acquisition&at_ptr_type=&at_ptr_name=bbc.comhp&at_format=Module&at_link_origin=homepage&at_campaign=essentiallist&at_campaign_type=owned
# Sign up to News BriefingNews and expert analysis for every schedule. Get the morning and evening edi - https://cloud.email.bbc.com/bbcnewsignup2?&at_bbc_team=studios&at_medium=display&at_objective=acquisition&at_ptr_type=&at_ptr_name=bbc.comhp&at_format=Module&at_link_origin=homepage&at_campaign=newsbriefing&at_campaign_type=owned

# %%
def fetch_news(homepage_url: str) -> list:

    """
    Fetches news items from the given homepage URL.
    Args:
        homepage_url (str): The URL of the news homepage to scrape.
    Returns:
        list: A list of dictionaries containing news titles and URLs.
        {"title": "News Title", "url": "https://example.com/news-item"}
    """

    resp = requests.get(homepage_url)
    soup = BeautifulSoup(resp.text, "html.parser")
    headings = ["h1", "h2", "h3", "h4", "h5", "h6"]
    news_items = []
    for item in soup.find_all("a"):
        if any(item.find(heading) for heading in headings):
            title = item.text.strip()
            url = item.get("href")
            if url and not url.startswith("http"):
                url = homepage_url + url
            news_items.append({"title": title, "url": url})
    for hd in headings:
        for item in soup.find_all(hd):
            if item.text.strip():
                title = item.text.strip()
                url = item.find("a").get("href") if item.find("a") else None
                if not url:
                    continue
                if url and not url.startswith("http"):
                    url = homepage_url + url
                news_items.append({"title": title, "url": url})
    return news_items

# %%
fetch_news("https://www.bbc.com/")
# Out:
# [{'title': "LIVEIsrael attacks Fordo nuclear site, as Trump floats 'regime change' after US strikes",
#   'url': 'https://www.bbc.com/news/live/cn7ze4vmk2pt'},
#  {'title': 'What is the Strait of Hormuz and why does it matter?',
#   'url': 'https://www.bbc.com//news/articles/c78n6p09pzno'},
#  {'title': 'LIVEBBC Verify Live: What satellite images tell us about damage in Iran',
#   'url': 'https://www.bbc.com//news/live/c75rw1d3vwnt'},
#  {'title': 'An unprecedented moment - but what the US and Iran do next could be even more momentous',
#   'url': 'https://www.bbc.com//news/articles/cy0w94yj68xo'},
#  {'title': 'How successful have the US strikes on Iran been?',
#   'url': 'https://www.bbc.com//news/videos/cq53l9dvggjo'},
#  {'title': 'Bride shot dead in attack on French wedding partyA suspected attacker is also killed in an apparent exchange of fire in a village near Avignon.11 hrs agoEurope',
#   'url': 'https://www.bbc.com//news/articles/cn0q8pypxwxo'},
#  {'title': 'First celestial image unveiled from revolutionary telescopeThe telescope should detect killer asteroids and may even find the ninth planet in our solar system.8 hrs agoScience & Environment',
#   'url': 'https://www.bbc.com//news/articles/cj3rmjjgx6xo'},
#  {'title': 'Bride shot dead in attack on French wedding partyA suspected attacker is also killed in an apparent exchange of fire in a village near Avignon.11 hrs agoEurope',
#   'url': 'https://www.bbc.com//news/articles/cn0q8pypxwxo'},
#  {'title': 'First celestial image unveiled from revolutionary telescopeThe telescope should detect killer asteroids and may even find the ninth planet in our solar system.8 hrs agoScience & Environment',
#   'url': 'https://www.bbc.com//news/articles/cj3rmjjgx6xo'},
#  {'title': 'Seven killed in Kyiv in new Russian aerial attack',
#   'url': 'https://www.bbc.com//news/articles/c0k7vll16l3o'},
#  {'title': "Russia's economy is down but not outThe country's economy has been surprisingly resilient but there are underlying problems.5 hrs agoEurope",
#   'url': 'https://www.bbc.com//news/articles/cpqnj17vryjo'},
#  {'title': 'Gilgeous-Alexander guides Thunder to NBA gloryShai Gilgeous-Alexander caps a dominant season as the Oklahoma City Thunder clinch the NBA Championship.5 hrs agoBasketball',
#   'url': 'https://www.bbc.com//sport/basketball/articles/c4gdp135vvgo'},
#  {'title': "'Our sister died of cancer because of our mum's conspiracy theories'Paloma Shemirani’s brothers say she refused chemotherapy because of their mother’s beliefs.7 hrs agoHealth",
#   'url': 'https://www.bbc.com//news/articles/crenzwyvpn1o'},
#  {'title': 'Why Alcaraz is \'red-hot favourite\' for third Wimbledon titleCarlos Alcaraz arrived in London with "no expectations" but, with Wimbledon only eight days away, he has sent an ominous message to his rivals.5 hrs agoTennis',
#   'url': 'https://www.bbc.com//sport/tennis/articles/cwyep8q2ge7o'},
#  {'title': "Why an apple a day is really good for youWe're told an apple a day keeps the doctor away, but does this humble fruit really have an outsized positive effect on our health?3 hrs agoFuture",
#   'url': 'https://www.bbc.com//future/article/20250620-is-an-apple-a-day-really-good-for-your-health'},
#  {'title': 'The story of the first ever Glastonbury FestivalAlmost 55 years ago, Michael Eavis hosted the first of his legendary music festivals. In 1970, the BBC visited his Somerset dairy farm to find out what made it so unique.1 hr agoCulture',
#   'url': 'https://www.bbc.com//culture/article/20250620-the-story-of-the-first-ever-glastonbury-festival-in-1970'},
#  {'title': 'US strikes Iran: UN chief warns against cycle of retaliation',
#   'url': 'https://www.bbc.com//audio/play/p0lkv3m9'},
#  {'title': 'Also in news', 'url': 'https://www.bbc.com/news/world'},
#  {'title': 'Indian investigators now claim all Pahalgam attackers were Pakistan nationalsIndian investigators have arrested two Kashmir residents who, they say, sheltered the attackers.4 hrs agoAsia',
#   'url': 'https://www.bbc.com//news/articles/c36xe95g06zo'},
#  {'title': 'LIVEBrook drops Rahul as cautious India slowly add to leadFollow live text updates from day four of the first Test between England and India at Headingley.',
#   'url': 'https://www.bbc.com/sport/cricket/live/c1751prexdpt'},
#  {'title': "How China made electric vehicles mainstreamThe world's second largest economy is both the biggest producer and buyer of EVs.12 hrs agoBusiness",
#   'url': 'https://www.bbc.com//news/articles/c2d5ld8y8pwo'},
#  {'title': 'Giant Michael Jackson statues popped up 30 years ago. Where have they gone?The King of Pop had 10 statues made in his image in 1995, but where can they be seen three decades later?2 days agoCulture',
#   'url': 'https://www.bbc.com//news/articles/cn0q2krypkro'},
#  {'title': "When Dubai almost became a part of India It's now largely forgotten that in the early 1900s, nearly a third of the Arabian Peninsula was under British India.2 days agoAsia",
#   'url': 'https://www.bbc.com//news/articles/cgq3wlp22j9o'},
#  {'title': 'LIVEBrook drops Rahul as cautious India slowly add to leadFollow live text updates from day four of the first Test between England and India at Headingley.',
#   'url': 'https://www.bbc.com/sport/cricket/live/c1751prexdpt'},
#  {'title': "Caught in the crossfire - the victims of Cape Town's gang warfareChildren are the unwitting casualties of the violence that has destroyed the lives of thousands.12 hrs agoAfrica",
#   'url': 'https://www.bbc.com//news/articles/c1mg2xg339jo'},
#  {'title': "'Tourists are our lifeline': Picking up the pieces in Kashmir after April killingsTwenty-six people were killed in an attack on tourists visiting a meadow near Pahalgam town in April.12 hrs agoAsia",
#   'url': 'https://www.bbc.com//news/articles/cly8lx75d6ro'},
#  {'title': "How China made electric vehicles mainstreamThe world's second largest economy is both the biggest producer and buyer of EVs.12 hrs agoBusiness",
#   'url': 'https://www.bbc.com//news/articles/c2d5ld8y8pwo'},
#  {'title': "Mexico's hidden 'bat volcano'Our reporter gets emotional visiting a hidden sinkhole in the Yucatan Peninsula, home to three million bats.2 hrs agoThe Travel Show",
#   'url': 'https://www.bbc.com//reel/video/p0ljyc5y/mexico-s-hidden-bat-volcano-'},
#  {'title': 'Satellite images and decoy planes: Behind the US attacks on IranIt took months of planning and included over 125 planes, a submarine and 14 "bunker buster" bombs. BBC Verify explains how the US mission "Operation Midnight Hammer" took place.18 hrs agoMiddle East',
#   'url': 'https://www.bbc.com//news/videos/cdezkx5nl1wo'},
#  {'title': "'Necessary' or 'unfounded'? Americans in Texas respond to US strikesThe BBC asked Texans and those visiting the state about US President Trump's decision to bomb three nuclear sites.13 hrs agoWorld",
#   'url': 'https://www.bbc.com//news/videos/c07dg04ke45o'},
#  {'title': 'Watch: Delivery rider throws water to trapped train passengersA delivery rider came to the aid of trapped train passengers by accurately throwing water bottles.19 hrs agoLondon',
#   'url': 'https://www.bbc.com//news/videos/c4geprerz5jo'},
#  {'title': 'US strikes on Iran trigger protests internationallyDemonstrators take to the streets in France, Pakistan, Greece and the Philippines to condemn the military action.10 hrs agoUS & Canada',
#   'url': 'https://www.bbc.com//news/videos/c4g2wxwel5qo'},
#  {'title': "The US has joined the Iran-Israel war. What happens now?The BBC's world news correspondent Joe Inwood answers three key questions after the US strikes in Iran.22 hrs agoMiddle East",
#   'url': 'https://www.bbc.com//news/videos/c5ypw09gdzpo'},
#  {'title': "Trump says strikes on Iran a 'spectacular military success' in addressThe US president warns Iran of future attacks if they retaliate.1 day agoWorld",
#   'url': 'https://www.bbc.com//news/videos/c93k8nvdnqpo'},
#  {'title': 'Yungblud festival draws fans from across the worldPeople travel from as far as Canada for Bludfest, a music and arts event founded by the rockstar.2 days agoBeds, Herts & Bucks',
#   'url': 'https://www.bbc.com//news/videos/c7vre6ggeqeo'},
#  {'title': 'Travel', 'url': 'https://www.bbc.com/travel'},
#  {'title': 'How self-drive tuk-tuks are transforming travel in Sri LankaA local startup is helping travellers experience the country like a local – and changing the lives of Sri Lankan families in the process.See more',
#   'url': 'https://www.bbc.com//travel/article/20250618-drive-your-own-tuk-tuk-in-sri-lanka'},
#  {'title': 'Technology', 'url': 'https://www.bbc.com/innovation/technology'},
#  {'title': 'The rock band that inspired the internetBefore the internet took over the world, California rock band The Grateful Dead were among the first – and most influential – forces at the dawn of online communication.See more',
#   'url': 'https://www.bbc.com//future/article/20250618-how-the-grateful-dead-shaped-social-media'},
#  {'title': 'US & Canada news', 'url': 'https://www.bbc.com/news/us-canada'},
#  {'title': 'Six dead and two missing after boat flips on Lake Tahoe Two survivors were also pulled from the rough waters and are being treated in hospital for hypothermia and other injuries.15 hrs agoUS & Canada',
#   'url': 'https://www.bbc.com//news/articles/cjwnl838pv3o'},
#  {'title': "Minnesota shootings suspect was a 'prepper', FBI says2 days agoUS & Canada",
#   'url': 'https://www.bbc.com//news/articles/c89ev9j955ko'},
#  {'title': 'Hundreds of Voice of America reporters fired as Trump guts outlet2 days agoUS & Canada',
#   'url': 'https://www.bbc.com//news/articles/cgrx0e98peeo'},
#  {'title': 'Man accused of forcing US congressman off road turns himself in2 days agoUS & Canada',
#   'url': 'https://www.bbc.com//news/articles/c80pl1ljkd8o'},
#  {'title': 'More world news', 'url': 'https://www.bbc.com/news'},
#  {'title': 'Iran still has an off-ramp for diplomacy, says LammyIran has said there will be "everlasting consequences" to three US strikes at the weekend.46 mins agoMiddle East',
#   'url': 'https://www.bbc.com//news/articles/c20pw5rrn0zo'},
#  {'title': 'Dozens of soldiers seized by locals in Colombian mountains7 hrs agoLatin America',
#   'url': 'https://www.bbc.com//news/articles/c4gdlrk1pzko'},
#  {'title': "Chris Mason: UK backs US's goals but not its methods in Iran12 hrs agoMiddle East",
#   'url': 'https://www.bbc.com//news/articles/cwyep25p5d0o'},
#  {'title': 'Suicide bombing at Damascus church kills 22, Syrian authorities say14 hrs agoMiddle East',
#   'url': 'https://www.bbc.com//news/articles/c307n9p43z9o'},
#  {'title': 'Sport', 'url': 'https://www.bbc.com/sport'},
#  {'title': "Lions demand Australia stars play in tour gamesThe British and Irish Lions have warned Australia the Wallabies' superstars must appear for their Super Rugby sides in the tourists' pre-Test series matches. 27 mins agoBritish & Irish Lions",
#   'url': 'https://www.bbc.com//sport/rugby-union/articles/c20np7x17zpo'},
#  {'title': 'US captain Bradley open to Ryder Cup playing role45 mins agoGolf',
#   'url': 'https://www.bbc.com//sport/golf/articles/c2d0xd403g8o'},
#  {'title': 'LIVECounty Championship day two - Archer back after 1,501 days, Anderson strikes twice for Lancs',
#   'url': 'https://www.bbc.com/sport/cricket/live/cgmjdkn912rt'},
#  {'title': 'LIVEClub World Cup: Talking points, new rules, innovations and your views as City win',
#   'url': 'https://www.bbc.com/sport/football/live/c8j1y1me11gt'},
#  {'title': 'Business', 'url': 'https://www.bbc.com/business'},
#  {'title': "US asks China to stop Iran from closing Strait of HormuzIran's Press TV had earlier reported that parliament had approved a plan to close the Strait.4 hrs agoBusiness",
#   'url': 'https://www.bbc.com//news/articles/c056pyv723vo'},
#  {'title': 'FedEx founder and former boss Fred Smith dies aged 801 day agoBusiness',
#   'url': 'https://www.bbc.com//news/articles/cvgw6nllwlwo'},
#  {'title': 'Cars, cash and a tycoon stirring debate in Zimbabwe1 day agoAfrica',
#   'url': 'https://www.bbc.com//news/articles/cn81ynyjy8no'},
#  {'title': 'Analysis: Russian government clearly nervous as country faces economic challenges2 days agoEurope',
#   'url': 'https://www.bbc.com//news/articles/cdr30jx6x0vo'},
#  {'title': 'Latest audio', 'url': 'https://www.bbc.com/audio'},
#  {'title': "The InterviewMartina Navratilova: 'Women are still judged by a different metric than men'",
#   'url': 'https://www.bbc.com//audio/play/w3ct7wzq'},
#  {'title': 'Global News PodcastIran condemns US attacks on its nuclear facilities',
#   'url': 'https://www.bbc.com//audio/play/p0lkslwg'},
#  {'title': 'Americast\u200b\u200bNewscast: The US Bombs Iranian Nuclear Sites',
#   'url': 'https://www.bbc.com//audio/play/p0lksj09'},
#  {'title': "Global News PodcastUS targets Iran's nuclear sites - extra edition",
#   'url': 'https://www.bbc.com//audio/play/p0lkr2f9'},
#  {'title': "Global News PodcastIsrael strikes Iran as US 'moves B-2 bombers'",
#   'url': 'https://www.bbc.com//audio/play/p0lkqc2j'},
#  {'title': 'The Global StoryThe President’s Path: Trump’s plan for Iran',
#   'url': 'https://www.bbc.com//audio/play/p0lknzq1'},
#  {'title': 'Football DailyThe Carlos Tevez Story',
#   'url': 'https://www.bbc.com//audio/play/p0lkkgry'},
#  {'title': "Global News PodcastThe Happy Pod: Sending my mother's ashes around the world",
#   'url': 'https://www.bbc.com//audio/play/p0lknbvr'},
#  {'title': 'Tech', 'url': 'https://www.bbc.com/innovation/technology'},
#  {'title': "Tesla robotaxi 'low-key' launch in Texas43 mins agoTechnology",
#   'url': 'https://www.bbc.com//news/articles/cjwnlje3yp1o'},
#  {'title': "Glastonbury begins and Squid Game ends: What's coming up this week19 hrs agoCulture",
#   'url': 'https://www.bbc.com//news/articles/cly39l8w6reo'},
#  {'title': 'Teens win awards at BAFTA game design competition1 day agoEngland',
#   'url': 'https://www.bbc.com//news/articles/cj4ed0qyp18o'},
#  {'title': 'Y2K core: Escapism and nostalgia for a time before you were born1 day ago',
#   'url': 'https://www.bbc.com//news/articles/cwyq17x1pllo'},
#  {'title': 'Science & health',
#   'url': 'https://www.bbc.com/innovation/science'},
#  {'title': 'Weight loss jab Mounjaro available to England NHS patients - but with strict rulesNHS England says the first patients able to get the jab will be those most in need.3 hrs agoHealth',
#   'url': 'https://www.bbc.com//news/articles/cglz4xyk7w9o'},
#  {'title': 'Does birth order shape your personality?2 days agoFuture',
#   'url': 'https://www.bbc.com//future/article/20250619-does-birth-order-shape-your-personality'},
#  {'title': 'Could ketamine on the NHS help treat severe depression?6 hrs agoScotland',
#   'url': 'https://www.bbc.com//news/articles/cyvjy7m3vmdo'},
#  {'title': "Stop telling me to lower my cortisol - it's making me stressed!2 days agoTechnology",
#   'url': 'https://www.bbc.com//news/articles/cg5z6l19rv6o'},
#  {'title': 'Culture', 'url': 'https://www.bbc.com/culture'},
#  {'title': 'The Scandi homeware style that Swedish people loveScandinavian interior style isn’t all about minimalist living and identikit furniture. Here\'s why abundance, exuberance and "luxe cosiness" are still popular today.1 day agoCulture',
#   'url': 'https://www.bbc.com//culture/article/20250620-the-true-scandi-style-that-swedes-love'},
#  {'title': 'Celebs say this gossip forum ruined their lives. Now its owner has been unmasked2 days agoCulture',
#   'url': 'https://www.bbc.com//news/articles/c5y7j512ln7o'},
#  {'title': "Kneecap performing at Glastonbury 'not appropriate', PM says2 days agoUK",
#   'url': 'https://www.bbc.com//news/articles/cg5z26dpgd7o'},
#  {'title': 'Prince William celebrates birthday with puppy photo2 days agoUK',
#   'url': 'https://www.bbc.com//news/articles/crk645er1kpo'},
#  {'title': 'Arts', 'url': 'https://www.bbc.com/arts'},
#  {'title': "Serpents to saints: The fascinating journey of India's spiritual art   A new exhibition at the British Museum in London traces the stunning evolution of India's devotional art through 189 objects. 3 days agoAsia",
#   'url': 'https://www.bbc.com//news/articles/cq69dn77577o'},
#  {'title': 'For 50 years, Sydney Opera House has had one man on speed dial2 days agoAustralia',
#   'url': 'https://www.bbc.com//news/articles/ckg6zzxq3v2o'},
#  {'title': "'Smoke and mirrors': Who was the real Andy Warhol?13 Jun 2025Culture",
#   'url': 'https://www.bbc.com//culture/article/20250611-who-was-the-real-andy-warhol'},
#  {'title': "Huge Roman 'jigsaw' reveals 2,000-year-old wall paintings4 days agoScience & Environment",
#   'url': 'https://www.bbc.com//news/articles/c5y5w1ldz8do'},
#  {'title': 'Watch', 'url': 'https://www.bbc.com/video'},
#  {'title': 'Baby elephant takes a muddy tumbleWatch a funny fall turn serious as mum Cyclone steps in to protect her calf from a clumsy big brother.See more',
#   'url': 'https://www.bbc.com//reel/video/p0lj6c2h/baby-elephant-takes-a-muddy-tumble'},
#  {'title': 'Travel', 'url': 'https://www.bbc.com/travel'},
#  {'title': "A technicolour visit to Morocco's holiest townClosed for centuries to outsiders, Moulay Idriss is a sacred place bathed in colour and tradition – and it makes a welcome respite from the crowds of Chefchaouen.2 days agoTravel",
#   'url': 'https://www.bbc.com//travel/article/20250620-a-technicolour-visit-to-moroccos-holiest-town'},
#  {'title': "Inside Bangkok's life-changing 'death cafe'3 days agoTravel",
#   'url': 'https://www.bbc.com//travel/article/20250618-the-bangkok-death-cafe-that-changed-my-life'},
#  {'title': 'The island city where Juneteenth was born4 days agoTravel',
#   'url': 'https://www.bbc.com//travel/article/20250618-the-island-city-where-juneteenth-was-born'},
#  {'title': "A day in Europe's most relaxed capital city5 days agoTravel",
#   'url': 'https://www.bbc.com//travel/article/20250618-why-oslo-might-be-europes-most-liveable-city-break'},
#  {'title': "World's Table", 'url': 'https://www.bbc.com/travel/worlds-table'},
#  {'title': 'Is there such a thing as American cuisine?For her new book, Peach Street to Lobster Lane, British food writer Felicity Cloake cycles across the US from coast to coast in search of a definition for its national cuisine.9 Jun 2025Travel',
#   'url': 'https://www.bbc.com//travel/article/20250606-felicity-cloakes-american-food-odyssey'},
#  {'title': 'Has matcha madness gone too far?7 Jun 2025Travel',
#   'url': 'https://www.bbc.com//travel/article/20250606-matcha-how-tourism-drained-a-japanese-town'},
#  {'title': 'How WW2 changed the French diet6 Jun 2025Travel',
#   'url': 'https://www.bbc.com//travel/article/20250605-how-world-war-two-changed-the-french-diet'},
#  {'title': 'Eight rare juices you can only try in the Amazon2 Jun 2025Travel',
#   'url': 'https://www.bbc.com//travel/article/20250529-eight-rare-juices-you-can-only-try-in-the-amazon'},
#  {'title': 'Earth', 'url': 'https://www.bbc.com/future-planet'},
#  {'title': 'The photos showing the softer side of great whitesFifty years since the release of Jaws, these photographers are showing a different, less frightening view of great white sharks.5 days agoFuture',
#   'url': 'https://www.bbc.com//future/article/20250617-photos-showing-softer-side-great-white-sharks-overturning-bad-image-jaws'},
#  {'title': "King's Midwinter message to Antarctic researchers2 days agoClimate",
#   'url': 'https://www.bbc.com//news/articles/cn9yxv2lvl0o'},
#  {'title': 'How do zoo animals keep cool in a heatwave?2 days agoEngland',
#   'url': 'https://www.bbc.com//news/articles/c0l48x9rywpo'},
#  {'title': 'Plastic bag bans and fees curb US shoreline litter, study suggests4 days agoScience & Environment',
#   'url': 'https://www.bbc.com//news/articles/cdeznkxyek0o'},
#  {'title': 'Video', 'url': 'https://www.bbc.com/video'},
#  {'title': "The science behind brewing tastier non-alcoholic beerUK brewery Wiper and True shows the BBC's Tech Now team a pioneering technique to craft alcohol-free beer.3 days agoTech Now",
#   'url': 'https://www.bbc.com//reel/video/p0ljxvlq/the-science-behind-brewing-tastier-non-alcoholic-beer'},
#  {'title': 'The ancient Mexican temple built to honour a serpent God4 days agoThe Travel Show',
#   'url': 'https://www.bbc.com//reel/video/p0ljkzz3/the-ancient-mexican-temple-built-to-honour-a-serpent-god'},
#  {'title': 'Even giant dinosaurs have a soft spot5 days agoNatural wonders',
#   'url': 'https://www.bbc.com//reel/video/p0ljxkbc/even-giant-dinosaurs-have-a-soft-spot'},
#  {'title': 'The most surprising sex-positive city in Europe7 days agoThe SpeciaList',
#   'url': 'https://www.bbc.com//reel/video/p0lj4tsp/the-most-surprising-sex-positive-city-in-europe'},
#  {'title': 'Football ExtraThe latest news, insights and gossip from the Premier League, direct to your inbox every weekday from ex-player Pat Nevin and the wider BBC Sport squad.',
#   'url': 'https://cloud.email.bbc.com/FootballExtra_Newsletter_Signup?&at_bbc_team=studios&at_medium=display&at_objective=acquisition&at_ptr_type=&at_ptr_name=bbc.comhp&at_format=Module&at_link_origin=homepage&at_campaign=footballextra&at_campaign_type=owned'},
#  {'title': 'Download the BBC appClick here to download the BBC app for Apple and Android devices.',
#   'url': 'https://bbc-global.onelink.me/Ezi6/n4y4nlv7'},
#  {'title': 'Health FixTrusted insights for better health and wellbeing rooted in science, every Wednesday to your inbox.',
#   'url': 'https://cloud.email.bbc.com/HealthFix_Newsletter_Signup?&at_bbc_team=studios&at_medium=emails&at_objective=acquisition&at_ptr_type=&at_ptr_name=bbc.com&at_format=Module&at_link_origin=homepage&at_campaign=healthfix&at_campaign_type=owned'},
#  {'title': "Register for a BBC accountDon't have time to read everything right now? Your BBC account lets you save articles and videos for later.",
#   'url': 'https://account.bbc.com/auth/register/email?ab=o13&action=register&clientId=Account&context=international&isCasso=false&nonce=ZhRJnl8N-Nzg4mlepfcUAP3WaQY2IhgqHUUw&ptrt=https%3A%2F%2Fwww.bbc.com%2F&realm=%2F&redirectUri=https%3A%2F%2Fsession.bbc.com%2Fsession%2Fcallback%3Frealm%3D%2F&sequenceId=afd616da-9f13-432d-a54d-95c9f32d1f0b&service=IdRegisterService&userOrigin=BBCS_BBC'},
#  {'title': 'Sign up for the Essential ListThe week’s best stories, handpicked by BBC editors, in your inbox every Tuesday and Friday.',
#   'url': 'https://cloud.email.bbc.com/SignUp10_08?&at_bbc_team=studios&at_medium=display&at_objective=acquisition&at_ptr_type=&at_ptr_name=bbc.comhp&at_format=Module&at_link_origin=homepage&at_campaign=essentiallist&at_campaign_type=owned'},
#  {'title': 'Sign up to News BriefingNews and expert analysis for every schedule. Get the morning and evening editions of our flagship newsletter in your inbox.',
#   'url': 'https://cloud.email.bbc.com/bbcnewsignup2?&at_bbc_team=studios&at_medium=display&at_objective=acquisition&at_ptr_type=&at_ptr_name=bbc.comhp&at_format=Module&at_link_origin=homepage&at_campaign=newsbriefing&at_campaign_type=owned'}]

# %%
resp  = requests.get("https://www.bbc.com/search?q=israel iran war")

# %%
soup = BeautifulSoup(resp.text, "html.parser")

# %%
results = soup.find_all("div", {"data-testid": "newport-card"})

# %%
for r in results:
    anchor = r.find("a", href=True)
    link = anchor["href"]
    if not link.startswith("http"):
        link = "https://www.bbc.co.uk" + link

    title_tag = r.find("h2")
    title = title_tag.get_text(strip=True) if title_tag else None

    description_tag = r.find("div", class_="sc-cdecfb63-3")
    description = description_tag.get_text(strip=True) if description_tag else None

    time_tag = r.find("span", attrs={"data-testid": "card-metadata-lastupdated"})
    time = time_tag.get_text(strip=True) if time_tag else None
    print(f"Title: {title}\nLink: {link}\nDescription: {description}\nTime: {time}\n")
# Out:
# Title: Iran warns Trump against joining war with Israel
# Link: https://www.bbc.co.uk/audio/play/p0lk00rz
# Description: Iran's supreme leader Ayatollah Ali Khamenei says Iran will never surrender
# Time: 5 days ago
#
# Title: Israel-Iran war leads to spike in energy prices
# Link: https://www.bbc.co.uk/audio/play/m002dks2
# Description: Oil prices jump as tensions rise in the Middle East.
# Time: 7 days ago
#
# Title: The US has joined the Iran-Israel war. What happens now?
# Link: https://www.bbc.co.uk/news/videos/c5ypw09gdzpo
# Description: The BBC's world news correspondent Joe Inwood answers three key questions after the US strikes in Iran.
# Time: 22 hrs ago
#
# Title: Americanswers… On 5 Live! Can Donald Trump stop the war between Israel and Iran?
# Link: https://www.bbc.co.uk/audio/play/p0ljn2p3
# Description: And which world leaders will the US President take advice from?
# Time: 7 days ago
#
# Title: 'Nowhere feels safe': Iranians on life under Israeli attacks
# Link: https://www.bbc.co.uk/news/articles/c8xgxdr01wro
# Description: Some of those in Iran who have spoken to the BBC use one word to describe life in there right now.
# Time: 8 days ago
#
# Title: Israel bombs Iran state TV during live broadcast
# Link: https://www.bbc.co.uk/news/articles/c3w46pw2xn0o
# Description: Israel's military says it struck a "communications centre of the Iranian regime", but Iran calls the attack a "war crime".
# Time: 6 days ago
#
# Title: US joining Israeli strikes would cause hell, Iranian minister tells BBC
# Link: https://www.bbc.co.uk/news/articles/c5y0wznr7wko
# Description: Iran's Deputy Foreign Minister Saeed Khatibzadeh told the BBC that this is "not America's war".
# Time: 4 days ago
#
# Title: BBC on the scene at Israeli hospital struck by Iranian missile
# Link: https://www.bbc.co.uk/news/videos/c3d1vlgkde7o
# Description: The BBC's Lucy Williamson is outside Soroka Hospital in Beersheba, south of Israel, as emergency workers assess the scene.
# Time: 4 days ago
#
# Title: 'I was lying in bed... The ceiling fell in': At the scene of Israeli hospital hit by Iran strike
# Link: https://www.bbc.co.uk/news/articles/c4gel0dd5y9o
# Description: A hospital in the Israeli town of Beersheba was hit as Iran fired a barrage of missiles at the country.
# Time: 4 days ago

# %%
def search_bbc(query: str) -> list:
    """
    Searches BBC for news articles related to the given query.
    Args:
        query (str): The search term to look for.
    Returns:
        list: A list of dictionaries containing article titles, URLs, descriptions, and publication times.
        {
            "title": "Article Title",
            "url": "https://www.bbc.com/article-url",
            "description": "Brief description of the article.",
            "time": "Publication time"
        }
    """
    search_url = f"https://www.bbc.com/search?q={query}"
    resp = requests.get(search_url)
    soup = BeautifulSoup(resp.text, "html.parser")
    results = soup.find_all("div", {"data-testid": "newport-card"})
    
    articles = []
    for r in results:
        anchor = r.find("a", href=True)
        link = anchor["href"]
        if not link.startswith("http"):
            link = "https://www.bbc.co.uk" + link

        title_tag = r.find("h2")
        title = title_tag.get_text(strip=True) if title_tag else None

        description_tag = r.find("div", class_="sc-cdecfb63-3")
        description = description_tag.get_text(strip=True) if description_tag else None

        time_tag = r.find("span", attrs={"data-testid": "card-metadata-lastupdated"})
        time = time_tag.get_text(strip=True) if time_tag else None
        
        articles.append({
            "title": title,
            "url": link,
            "description": description,
            "time": time
        })
    
    return articles

# %%
search_bbc("FIFA Pakistan")
# Out:
# [{'title': 'African legends bring hope to Somali football',
#   'url': 'https://www.bbc.co.uk/sport/football/articles/cdxvw2yvqgno',
#   'description': "Somalians hope hosting Emmanuel Adebayor, Samuel Eto'o and Jay Jay Okocha in a legends game can help bring international football back to the country after nearly 40 years.",
#   'time': '30 May 2025'},
#  {'title': "Human rights groups warn of 'surge' in migrant worker deaths in Saudi Arabia",
#   'url': 'https://www.bbc.co.uk/news/articles/cgj86wqe0dlo',
#   'description': 'Workers are already dying from preventable workplace accidents as the country prepares to host the 2034 World Cup, reports say.',
#   'time': '14 May 2025'},
#  {'title': 'Congo-Brazzaville suspended from international football',
#   'url': 'https://www.bbc.co.uk/sport/football/articles/cx2513r30v6o',
#   'description': "Football's world governing body suspends Congo-Brazzaville from internationals because of third-party interference in the affairs of the country's FA.",
#   'time': '7 Feb 2025'},
#  {'title': 'Why are Australia so much better than England?',
#   'url': 'https://www.bbc.co.uk/sport/cricket/articles/c04nepk34pdo',
#   'description': "BBC cricket reporter Henry Moeran explores the possible reasons why the gap in quality between Australia and England is so significant in women's cricket.",
#   'time': '28 Jan 2025'},
#  {'title': 'The Englishmen making a managerial mark around the world',
#   'url': 'https://www.bbc.co.uk/sport/football/articles/cr56jr7zdrqo',
#   'description': 'England appointed German Thomas Tuchel but there is no shortage of English-born coaches in charge of national teams across the globe.',
#   'time': '7 Jan 2025'},
#  {'title': 'Sunil Chhetri: Indian footballer in the same league as Messi and Ronaldo',
#   'url': 'https://www.bbc.co.uk/news/world-asia-india-66106345',
#   'description': 'Long-standing captain Sunil Chhetri has been the face of football in cricket-crazy India.',
#   'time': '5 Jul 2023'},
#  {'title': 'World sport: 10 photos we liked this week',
#   'url': 'https://www.bbc.co.uk/sport/44825683',
#   'description': 'A selection of the most striking sports photographs from around the world this week.',
#   'time': '17 Jul 2018'},
#  {'title': 'The numbers that make 2022 World Cup so different',
#   'url': 'https://www.bbc.co.uk/sport/football/63118686',
#   'description': 'The World Cup in Qatar starts on Sunday in what promises to be a unique tournament. So what makes it so different?',
#   'time': '18 Nov 2022'},
#  {'title': 'Young refs inspired by seeing hijab at World Cup',
#   'url': 'https://www.bbc.co.uk/news/uk-wales-66550303',
#   'description': "Teenagers Rosheen and Eleeza Khan are Wales' first Muslim female football referees.",
#   'time': '19 Aug 2023'}]
